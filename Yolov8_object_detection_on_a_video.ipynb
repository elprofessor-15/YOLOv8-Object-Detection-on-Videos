# %%
# Install necessary packages
# !pip install -U ultralytics opencv-python pytube
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.7/881.7 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import cv2
import torch
import os
from pytube import YouTube
import matplotlib.pyplot as plt

# %%
import cv2
from ultralytics import YOLO

# Load the pre-trained YOLOv8 model
model = YOLO('yolov8s.pt')  # This loads the small YOLOv8 model

# Specify the path to the input and output video
input_video_path = '/content/traffic video .mp4'
output_video_path = '/content/output_video_with_detections.mp4'

# Function to process the video and save output with detections
def process_and_save_video(input_video_path, output_video_path):
    # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    # Check if video opened successfully
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    # Get video properties such as width, height, and frame rate
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create a VideoWriter object to save the video
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    # Loop through each frame of the video
    while cap.isOpened():
        ret, frame = cap.read()  # Read each frame

        if not ret:
            break  # Exit if there are no more frames

        # Perform object detection on the frame
        results = model(frame)  # This returns the detection results

        # Draw bounding boxes and labels on the frame
        annotated_frame = results[0].plot()  # Plot results directly on the frame

        # Write the annotated frame to the output video
        out.write(annotated_frame)

    # Release the video capture and writer objects
    cap.release()
    out.release()
    cv2.destroyAllWindows()

# Process the video and save the output with object detection
process_and_save_video(input_video_path, output_video_path)

# Output path of the video
print(f"Output video saved at: {output_video_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Speed: 3.1ms preprocess, 398.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 3 trucks, 380.7ms
# Speed: 4.9ms preprocess, 380.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 3 trucks, 413.9ms
# Speed: 5.1ms preprocess, 413.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 3 trucks, 380.5ms
# Speed: 3.5ms preprocess, 380.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 4 trucks, 393.1ms
# Speed: 4.8ms preprocess, 393.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 3 trucks, 390.3ms
# Speed: 4.6ms preprocess, 390.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 3 trucks, 383.5ms
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the pre-trained YOLOv8 model
model = YOLO('yolov8s.pt')  # This loads the small YOLOv8 model

# Specify the path to the input and output video
input_video_path = '/content/pedestrian_traffic.mp4'
output_video_path = '/content/output_pedestrian_traffic_with_detections.mp4'

# Function to process the video and save output with detections
def process_and_save_video(input_video_path, output_video_path):
    # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    # Check if video opened successfully
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    # Get video properties such as width, height, and frame rate
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create a VideoWriter object to save the video
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    # Loop through each frame of the video
    while cap.isOpened():
        ret, frame = cap.read()  # Read each frame

        if not ret:
            break  # Exit if there are no more frames

        # Perform object detection on the frame
        results = model(frame)  # This returns the detection results

        # Draw bounding boxes and labels on the frame
        annotated_frame = results[0].plot()  # Plot results directly on the frame

        # Write the annotated frame to the output video
        out.write(annotated_frame)

    # Release the video capture and writer objects
    cap.release()
    out.release()
    cv2.destroyAllWindows()

# Process the video and save the output with object detection
process_and_save_video(input_video_path, output_video_path)

# Output path of the video
print(f"Output video saved at: {output_video_path}")
# Out:
# 0: 384x640 (no detections), 502.2ms
# Speed: 16.2ms preprocess, 502.2ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 366.6ms
# Speed: 3.5ms preprocess, 366.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 375.6ms
# Speed: 3.5ms preprocess, 375.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.1ms
# Speed: 3.1ms preprocess, 352.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 342.5ms
# Speed: 2.7ms preprocess, 342.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.7ms
# Speed: 5.5ms preprocess, 363.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.2ms
# Speed: 3.3ms preprocess, 348.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the pre-trained YOLOv8 model
model = YOLO('yolov8s.pt')  # This loads the small YOLOv8 model

# Specify the path to the input and output video
input_video_path = '/content/sample_video_3_varanasi_pedestrian_video.mp4'
output_video_path = '/content/output_video_3_varanasi_pedestrian_video_with_detections.mp4'

# Function to process the video and save output with detections
def process_and_save_video(input_video_path, output_video_path):
    # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    # Check if video opened successfully
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    # Get video properties such as width, height, and frame rate
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create a VideoWriter object to save the video
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    # Loop through each frame of the video
    while cap.isOpened():
        ret, frame = cap.read()  # Read each frame

        if not ret:
            break  # Exit if there are no more frames

        # Perform object detection on the frame
        results = model(frame)  # This returns the detection results

        # Draw bounding boxes and labels on the frame
        annotated_frame = results[0].plot()  # Plot results directly on the frame

        # Write the annotated frame to the output video
        out.write(annotated_frame)

    # Release the video capture and writer objects
    cap.release()
    out.release()
    cv2.destroyAllWindows()

# Process the video and save the output with object detection
process_and_save_video(input_video_path, output_video_path)

# Output path of the video
print(f"Output video saved at: {output_video_path}")
# Out:
# 0: 384x640 16 persons, 1 handbag, 569.4ms
# Speed: 4.9ms preprocess, 569.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 handbag, 556.7ms
# Speed: 4.9ms preprocess, 556.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 suitcase, 565.0ms
# Speed: 6.2ms preprocess, 565.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 handbag, 574.8ms
# Speed: 2.9ms preprocess, 574.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 460.1ms
# Speed: 4.4ms preprocess, 460.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 347.3ms
# Speed: 4.6ms preprocess, 347.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 handbag, 1 suitcase, 375.7ms
# ...
